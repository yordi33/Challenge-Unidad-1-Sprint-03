# %% [markdown]
# ![cabecera](data:image/png;base64,...)

# %% [markdown]
# # Gemini — hola mundo
#
# **Requisitos:** entorno virtual activo (`.venv`) con `pip install -r requirements.txt` y kernel apuntando a ese Python.
#
# API key: [Google AI Studio](https://aistudio.google.com/)

# %% [markdown]
# ## 0) Instalación
#
# Ejecuta esta celda una vez (con el kernel del `.venv` de esta carpeta). Incluye `python-dotenv` para leer el fichero `.env`.

# %%
# %pip install -U google-genai python-dotenv

# %% [markdown]
# ## 1) Configurar la API key
#
# 1. Copia `.env.example` a `.env` y pega tu clave de [Google AI Studio](https://aistudio.google.com/).
# 2. Esta celda ejecuta `load_dotenv()` para cargar `.env`.
# 3. Si no hay clave, te la pedirá con `getpass` (solo esta sesión).

# %%
# Ejemplo de script para ejecutar nuestro proyecto
import os
import getpass

from dotenv import load_dotenv
from google import genai

load_dotenv()  # carga variables desde .env (si existe)

if not os.getenv("GEMINI_API_KEY"):
    os.environ["GEMINI_API_KEY"] = getpass.getpass(
        "Pega aquí tu GEMINI_API_KEY (input oculto): "
    )

print("GEMINI_API_KEY configurada:", "sí" if os.getenv("GEMINI_API_KEY") else "no")

# %% [markdown]
# ## 2) Primera llamada (texto)
#
# Si todo está bien, deberías ver una respuesta en texto.

# %%
client = genai.Client()
MODEL = "gemini-3-flash-preview"

response = client.models.generate_content(
    model=MODEL,
    contents="Resume en 3 frases qué es la IA generativa.",
)

print(response.text)
